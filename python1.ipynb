# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\manje\\OneDrive\\Desktop\\pradhanmatri\\headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = data['Head Size(cm^3)'].values
Y = data['Brain Weight(grams)'].values

# %%
mean_x=np.mean(X)
mean_y=np.mean(Y)
n = len(X)
m=len(Y)
print(mean_x)
print(mean_y)
print(n)
print(m)
# Out:
# 3633.9915611814345
# 1282.873417721519
# 237
# 237

# %%
b1 = np.sum((X - mean_x) * (Y - mean_y)) / np.sum((X - mean_x) ** 2)
b0 = mean_y - b1 * mean_x

# %%
print("Coefficients")
print(b1)
print(b0)
# Out:
# Coefficients
# 0.2634293394893993
# 325.5734210494428

# %%
x = np.linspace(np.min(X) - 100, np.max(X) + 100, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y, color='green', label='Regression Line')
plt.scatter(X, Y, c='red', label='Scatter Plot')
plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()

# %%
r2 = 1 - (np.sum((Y - (b0 + b1 * X)) ** 2) / np.sum((Y - mean_y) ** 2))
print("R2 Score")
print(r2)
# Out:
# R2 Score
# 0.639311719957
